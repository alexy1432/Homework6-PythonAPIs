# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
from pprint import pprint 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?appid="
url2 = url + api_key + "&q="
cities2 = []
cities3 = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
MaxTemp = []
WindSpeed = []
counter = 1
#loop through cities to create url
print("Beginning Data Retrieval")
print("------------------------")
for x in cities:
    url3 = url2+x
    weather = requests.get(url3).json()
    print("Processing Record " + str(len(cities2)) + " of Set " + str(counter) +" | "+ x)
#if city does not exist, it will skip - weather["name"] will not be included in dataframe 
    try: 
        weather["name"]
#create 2 city lists - cities2 gets reset every 50 iterations, cities3 is masterlist        
        cities2.append(x)
        cities3.append(x)
        Cloudiness.append(weather["clouds"]["all"])
        Country.append(weather["sys"]["country"])
        Date.append(weather["dt"])
        Humidity.append(weather["main"]["humidity"])
        Lat.append(weather["coord"]["lat"])
        Lng.append(weather["coord"]["lon"])
        MaxTemp.append(weather["main"]["temp_max"])
        WindSpeed.append(weather["wind"]["speed"])
    except:
        print("City not found. Skipping...")
#creates a new set of cities every 50 cities        
    if len(cities2)==50:
        counter +=1
        cities2 = []
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 of Set 1 | ushuaia
# Processing Record 1 of Set 1 | kibala
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | kukushtan
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | namatanai
# Processing Record 6 of Set 1 | ramgarh
# Processing Record 7 of Set 1 | nelson bay
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | midland
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | kavaratti
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | atasu
# Processing Record 19 of Set 1 | sur
# Processing Record 20 of Set 1 | hami
# Processing Record 21 of Set 1 | atar
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | san quintin
# Processing Record 24 of Set 1 | riyadh
# Processing Record 25 of Set 1 | thinadhoo
# Processing Record 26 of Set 1 | vuktyl
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | sabang
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | lagoa
# Processing Record 31 of Set 1 | tual
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | vila
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | banjar
# Processing Record 36 of Set 1 | coihaique
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | xihe
# Processing Record 39 of Set 1 | faro
# Processing Record 40 of Set 1 | didsbury
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | camapua
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | pisco
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | busselton
# Processing Record 35 of Set 4 | turan
# Processing Record 36 of Set 4 | muskogee
# Processing Record 37 of Set 4 | djenne
# Processing Record 38 of Set 4 | san joaquin
# Processing Record 39 of Set 4 | eyl
# Processing Record 40 of Set 4 | tura
# Processing Record 41 of Set 4 | palotina
# Processing Record 42 of Set 4 | poum
# Processing Record 43 of Set 4 | omsukchan
# Processing Record 44 of Set 4 | san policarpo
# Processing Record 45 of Set 4 | makakilo city
# Processing Record 46 of Set 4 | suntar
# Processing Record 47 of Set 4 | tolaga bay
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | byron bay
# Processing Record 0 of Set 5 | blechepsin
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | muros
# Processing Record 3 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 5 | aksarka
# Processing Record 4 of Set 5 | digha
# Processing Record 5 of Set 5 | zyryanka
# Processing Record 6 of Set 5 | clyde river
# Processing Record 7 of Set 5 | chumikan
# Processing Record 8 of Set 5 | talnakh
# Processing Record 9 of Set 5 | oktyabrskiy
# Processing Record 10 of Set 5 | port blair
# Processing Record 11 of Set 5 | vardo
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | mugumu
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | klaksvik
# Processing Record 16 of Set 5 | nkhata bay
# Processing Record 17 of Set 5 | bulembu
# Processing Record 18 of Set 5 | hobyo
# Processing Record 19 of Set 5 | cayenne
# Processing Record 20 of Set 5 | abay
# Processing Record 21 of Set 5 | port elizabeth
# Processing Record 22 of Set 5 | esperance
# Processing Record 23 of Set 5 | wonthaggi
# Processing Record 24 of Set 5 | minsk
# Processing Record 25 of Set 5 | neiafu
# Processing Record 26 of Set 5 | puerto del rosario
# Processing Record 27 of Set 5 | laguna
# Processing Record 28 of Set 5 | skibbereen
# Processing Record 29 of Set 5 | yaan
# Processing Record 30 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 5 | yumen
# Processing Record 31 of Set 5 | lorengau
# Processing Record 32 of Set 5 | ribeira grande
# Processing Record 33 of Set 5 | kruisfontein
# Processing Record 34 of Set 5 | jinji
# Processing Record 35 of Set 5 | ilhabela
# Processing Record 36 of Set 5 | mehamn
# Processing Record 37 of Set 5 | svetlogorsk
# Processing Record 38 of Set 5 | fairbanks
# Processing Record 39 of Set 5 | stade
# Processing Record 40 of Set 5 | west odessa
# Processing Record 41 of Set 5 | longjiang
# Processing Record 42 of Set 5 | cabo san lucas
# Processing Record 43 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 5 | shingu
# Processing Record 44 of Set 5 | kieta
# Processing Record 45 of Set 5 | middleton
# Processing Record 46 of Set 5 | jeremie
# Processing Record 47 of Set 5 | katobu
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | vila franca do campo
# Processing Record 0 of Set 6 | havelock
# Processing Record 1 of Set 6 | biltine
# Processing Record 2 of Set 6 | provideniya
# Processing Record 3 of Set 6 | berlevag
# Processing Record 4 of Set 6 | dakar
# Processing Record 5 of Set 6 | rondonopolis
# Processing Record 6 of Set 6 | iqaluit
# Processing Record 7 of Set 6 | hailar
# Processing Record 8 of Set 6 | nhulunbuy
# Processing Record 9 of Set 6 | uong bi
# Processing Record 10 of Set 6 | sao joao da barra
# Processing Record 11 of Set 6 | hay river
# Processing Record 12 of Set 6 | opuwo
# Processing Record 13 of Set 6 | ostrovnoy
# Processing Record 14 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 6 | staryy nadym
# Processing Record 15 of Set 6 | zhucheng
# Processing Record 16 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 16 of Set 6 | victor harbor
# Processing Record 17 of Set 6 | soure
# Processing Record 18 of Set 6 | mogochin
# City not found. Skipping...
# Processing Record 18 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 6 | abrego
# Processing Record 19 of Set 6 | anadyr
# Processing Record 20 of Set 6 | leh
# Processing Record 21 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 6 | shahr-e babak
# Processing Record 22 of Set 6 | lompoc
# Processing Record 23 of Set 6 | charcas
# Processing Record 24 of Set 6 | pangoa
# Processing Record 25 of Set 6 | chumphon
# Processing Record 26 of Set 6 | monte azul
# Processing Record 27 of Set 6 | kysyl-syr
# Processing Record 28 of Set 6 | sorland
# Processing Record 29 of Set 6 | marihatag
# Processing Record 30 of Set 6 | nalut
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 6 | kulhudhuffushi
# Processing Record 32 of Set 6 | kuito
# Processing Record 33 of Set 6 | geraldton
# Processing Record 34 of Set 6 | chilca
# Processing Record 35 of Set 6 | arlit
# Processing Record 36 of Set 6 | dicabisagan
# Processing Record 37 of Set 6 | aleksinac
# Processing Record 38 of Set 6 | vieux-habitants
# Processing Record 39 of Set 6 | constitucion
# Processing Record 40 of Set 6 | bandarbeyla
# Processing Record 41 of Set 6 | ust-kulom
# Processing Record 42 of Set 6 | berbera
# City not found. Skipping...
# Processing Record 42 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 6 | puerto lempira
# Processing Record 43 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 43 of Set 6 | aykhal
# Processing Record 44 of Set 6 | hambantota
# Processing Record 45 of Set 6 | broome
# Processing Record 46 of Set 6 | puerto escondido
# Processing Record 47 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 6 | oltu
# Processing Record 48 of Set 6 | porbandar
# Processing Record 49 of Set 6 | chara
# Processing Record 0 of Set 7 | umm lajj
# Processing Record 1 of Set 7 | ati
# Processing Record 2 of Set 7 | xining
# Processing Record 3 of Set 7 | ewa beach
# Processing Record 4 of Set 7 | pecan grove
# Processing Record 5 of Set 7 | mahebourg
# Processing Record 6 of Set 7 | college
# Processing Record 7 of Set 7 | houma
# Processing Record 8 of Set 7 | yenagoa
# Processing Record 9 of Set 7 | tarakan
# Processing Record 10 of Set 7 | tocopilla
# Processing Record 11 of Set 7 | ahipara
# Processing Record 12 of Set 7 | rawson
# Processing Record 13 of Set 7 | tucuma
# City not found. Skipping...
# Processing Record 13 of Set 7 | evensk
# Processing Record 14 of Set 7 | presidente prudente
# Processing Record 15 of Set 7 | safaga
# City not found. Skipping...
# Processing Record 15 of Set 7 | balykshi
# City not found. Skipping...
# Processing Record 15 of Set 7 | pacific grove
# Processing Record 16 of Set 7 | sidney
# Processing Record 17 of Set 7 | suhl
# Processing Record 37 of Set 8 | boa vista
# Processing Record 38 of Set 8 | zhanaozen
# Processing Record 39 of Set 8 | saint-augustin
# Processing Record 40 of Set 8 | metro
# Processing Record 41 of Set 8 | camocim
# Processing Record 42 of Set 8 | shaikhpura
# Processing Record 43 of Set 8 | mponela
# Processing Record 44 of Set 8 | tautira
# Processing Record 45 of Set 8 | sioux lookout
# Processing Record 46 of Set 8 | sulangan
# Processing Record 47 of Set 8 | aljezur
# Processing Record 48 of Set 8 | bambanglipuro
# Processing Record 49 of Set 8 | faya
# Processing Record 0 of Set 9 | ngaoundere
# Processing Record 1 of Set 9 | grabovo
# Processing Record 2 of Set 9 | bathsheba
# Processing Record 3 of Set 9 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 3 of Set 9 | barra do garcas
# Processing Record 4 of Set 9 | san cristobal
# Processing Record 5 of Set 9 | behat
# Processing Record 6 of Set 9 | igarape-miri
# City not found. Skipping...
# Processing Record 6 of Set 9 | laredo
# Processing Record 7 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 9 | nabire
# Processing Record 8 of Set 9 | kargil
# Processing Record 9 of Set 9 | rajula
# Processing Record 10 of Set 9 | mbandaka
# Processing Record 11 of Set 9 | boffa
# Processing Record 12 of Set 9 | pontianak
# Processing Record 13 of Set 9 | ahome
# Processing Record 14 of Set 9 | kemijarvi
# City not found. Skipping...
# Processing Record 14 of Set 9 | khasan
# Processing Record 15 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 9 | nizhniy kuranakh
# Processing Record 16 of Set 9 | eureka
# Processing Record 17 of Set 9 | caledonia
# Processing Record 18 of Set 9 | kloulklubed
# Processing Record 19 of Set 9 | peto
# Processing Record 20 of Set 9 | bilma
# Processing Record 21 of Set 9 | avarua
# Processing Record 22 of Set 9 | ithaki
# Processing Record 23 of Set 9 | tam ky
# Processing Record 24 of Set 9 | gizo
# Processing Record 25 of Set 9 | manta
# Processing Record 26 of Set 9 | vangaindrano
# Processing Record 27 of Set 9 | sheopur
# Processing Record 28 of Set 9 | torrijos
# Processing Record 29 of Set 9 | ushtobe
# Processing Record 30 of Set 9 | san cosme y damian
# Processing Record 31 of Set 9 | kiama
# Processing Record 32 of Set 9 | misratah
# Processing Record 33 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 9 | tacuati
# Processing Record 35 of Set 9 | gyanpur
# Processing Record 36 of Set 9 | san rafael del sur
# Processing Record 37 of Set 9 | selma
# Processing Record 38 of Set 9 | ayagoz
# Processing Record 39 of Set 9 | poplevinskiy
# Processing Record 40 of Set 9 | baghdad
# Processing Record 41 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 9 | raton
# Processing Record 42 of Set 9 | bomet
# Processing Record 43 of Set 9 | lhokseumawe
# Processing Record 44 of Set 9 | mitchell
# Processing Record 45 of Set 9 | honiara
# Processing Record 46 of Set 9 | alenquer
# Processing Record 47 of Set 9 | samarai
# Processing Record 48 of Set 9 | kirakira
# Processing Record 49 of Set 9 | wagar
# Processing Record 0 of Set 10 | port keats
# Processing Record 1 of Set 10 | mianwali
# Processing Record 2 of Set 10 | port hope
# Processing Record 3 of Set 10 | gdansk
# Processing Record 4 of Set 10 | nemuro
# Processing Record 5 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 10 | benghazi
# Processing Record 6 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 10 | ula
# Processing Record 7 of Set 10 | sheffield
# Processing Record 8 of Set 10 | leshukonskoye
# Processing Record 9 of Set 10 | moerai
# Processing Record 10 of Set 10 | digby
# Processing Record 11 of Set 10 | phibun mangsahan
# Processing Record 12 of Set 10 | harjavalta
# Processing Record 13 of Set 10 | villa maria
# Processing Record 14 of Set 10 | burica
# City not found. Skipping...
# Processing Record 14 of Set 10 | babu
# Processing Record 15 of Set 10 | nyurba
# Processing Record 16 of Set 10 | daru
# Processing Record 17 of Set 10 | nizhyn
# Processing Record 18 of Set 10 | manggar
# Processing Record 19 of Set 10 | bantry
# City not found. Skipping...
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | lancut
# Processing Record 21 of Set 10 | bindura
# Processing Record 22 of Set 10 | haines junction
# Processing Record 23 of Set 10 | harer
# Processing Record 24 of Set 10 | caravelas
# Processing Record 25 of Set 10 | pangnirtung
# Processing Record 26 of Set 10 | iquique
# Processing Record 27 of Set 10 | tynda
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | algiers
# Processing Record 30 of Set 10 | bedford
# Processing Record 31 of Set 10 | carballo
# Processing Record 32 of Set 10 | petrolina
# Processing Record 33 of Set 10 | ambon
# Processing Record 34 of Set 10 | krasnoborsk
# Processing Record 35 of Set 10 | marquette
# Processing Record 36 of Set 10 | nueva loja
# Processing Record 37 of Set 10 | galich
# Processing Record 38 of Set 10 | shimoda
# Processing Record 39 of Set 10 | kargasok
# Processing Record 40 of Set 10 | mandalgovi
# Processing Record 41 of Set 10 | mimongo
# Processing Record 42 of Set 10 | honningsvag
# Processing Record 43 of Set 10 | tlapacoyan
# Processing Record 44 of Set 10 | bonfim
# Processing Record 45 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 45 of Set 10 | arkhara
# Processing Record 46 of Set 10 | sechura
# Processing Record 47 of Set 10 | great yarmouth
# Processing Record 48 of Set 10 | aswan
# Processing Record 49 of Set 10 | kaeo
# Processing Record 0 of Set 11 | okhotsk
# Processing Record 1 of Set 11 | itarema
# Processing Record 2 of Set 11 | santa comba
# Processing Record 3 of Set 11 | kalaleh
# Processing Record 4 of Set 11 | amasya
# Processing Record 5 of Set 11 | balaipungut
# Processing Record 6 of Set 11 | jinan
# Processing Record 7 of Set 11 | abeche
# Processing Record 8 of Set 11 | pierre
# Processing Record 9 of Set 11 | quatre cocos
# Processing Record 10 of Set 11 | karasjok
# Processing Record 11 of Set 11 | muisne
# Processing Record 12 of Set 11 | tommot
# Processing Record 13 of Set 11 | ambulu
# Processing Record 14 of Set 11 | asyut
# Processing Record 15 of Set 11 | khani
# Processing Record 16 of Set 11 | pathein
# Processing Record 17 of Set 11 | fortuna
# Processing Record 18 of Set 11 | tupik
# Processing Record 19 of Set 11 | porto velho
# Processing Record 20 of Set 11 | vetapalem
# Processing Record 21 of Set 11 | san rafael
# Processing Record 22 of Set 11 | morehead
# Processing Record 23 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 11 | kankakee
# Processing Record 24 of Set 11 | belaya gora
# Processing Record 25 of Set 11 | mocajuba
# Processing Record 26 of Set 11 | deputatskiy
# Processing Record 27 of Set 11 | namibe
# Processing Record 28 of Set 11 | krasnoselkup
# City not found. Skipping...
# Processing Record 28 of Set 11 | imeni poliny osipenko
# Processing Record 29 of Set 11 | koupela
# Processing Record 30 of Set 11 | lincoln
# Processing Record 31 of Set 11 | japura
# Processing Record 32 of Set 11 | bankja
# City not found. Skipping...
# Processing Record 32 of Set 11 | khor
# Processing Record 33 of Set 11 | aksu
# Processing Record 34 of Set 11 | pulgaon
# Processing Record 35 of Set 11 | agara
# Processing Record 36 of Set 11 | nizwa
# Processing Record 37 of Set 11 | malinyi
# Processing Record 38 of Set 11 | hare bay
# Processing Record 39 of Set 11 | challans
# Processing Record 40 of Set 11 | tahe
# Processing Record 41 of Set 11 | fort nelson
# Processing Record 42 of Set 11 | umkomaas
# Processing Record 43 of Set 11 | cotonou
# Processing Record 44 of Set 11 | wanning
# Processing Record 45 of Set 11 | jinchang
# Processing Record 46 of Set 11 | nueva guinea

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
 
#convert from Kelvin to Farenheit
MaxTemp2 = []
for x in MaxTemp:
    Farenheit = ((x-273.15)*(1.8)+32)
    MaxTemp2.append(Farenheit)
#convert from UNIX to readable Date
Date2 = []
for y in Date:
    time= datetime.datetime.fromtimestamp(int(y)).strftime('%Y-%m-%d')
    Date2.append(time)
WindSpeed2 = []
for z in WindSpeed:
    Speed = (z*1.60934)
    WindSpeed2.append(Speed)
df=pd.DataFrame({"City": cities3,"Cloudiness": Cloudiness, "Country":Country,"Date":Date2,"Humidity":Humidity,"Lat":Lat,
                "Lng":Lng,"Max Temp":MaxTemp2,"Wind Speed":WindSpeed2})
df.to_csv("CityWeatherData.csv")
df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0    ushuaia          75      AR  2019-06-25        92 -54.81 -68.31
# 1     kibala         100      TD  2019-06-25        92   9.11  18.35
# 2     albany          90      US  2019-06-25        93  42.65 -73.75
# 3  kukushtan          20      RU  2019-06-25        87  57.65  56.50
# 4      vaini          75      IN  2019-06-25        88  15.34  74.49
#
#    Max Temp  Wind Speed
# 0    30.200    2.414010
# 1    73.157    6.179866
# 2    73.400    4.216471
# 3    57.200    1.609340
# 4    75.200    4.988954

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(df["Lat"],df["Max Temp"],facecolors = "lightblue",edgecolor="black")
plt.grid()
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.title("City Latitude vs Max Temperature 6/25/2019")
plt.savefig("LatVsMaxTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df["Lng"],df["Humidity"],facecolors = "lightblue",edgecolor="black")
plt.grid()
plt.ylabel("Humidity (%)")
plt.xlabel("Longitude")
plt.title("City Longitude vs Humidity 6/25/2019")
plt.savefig("LngVsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df["Lat"],df["Cloudiness"],facecolors = "lightblue",edgecolor="black")
plt.grid()
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.title("City Latitude vs Cloudiness 6/25/2019")
plt.savefig("LatVsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df["Lat"],df["Wind Speed"],facecolors = "lightblue",edgecolor="black")
plt.grid()
plt.ylabel("Windspeed (mph)")
plt.xlabel("Latitude")
plt.title("City Latitude vs Wind Speed 6/25/2019")
plt.savefig("LatVsWindSpeed.png")
